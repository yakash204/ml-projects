# %% [markdown]
# <a href="https://colab.research.google.com/github/yakash204/ml-projects/blob/main/Intelligent_Infrastructure_Maintenance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://s3-ap-southeast-1.amazonaws.com/he-public-data/Training%20data%20set%201b23e3b4.zip
# Out:
# --2021-04-29 10:26:49--  https://s3-ap-southeast-1.amazonaws.com/he-public-data/Training%20data%20set%201b23e3b4.zip
# Resolving s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)... 52.219.124.62
# Connecting to s3-ap-southeast-1.amazonaws.com (s3-ap-southeast-1.amazonaws.com)|52.219.124.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 971014870 (926M) [binary/octet-stream]
# Saving to: ‘Training data set 1b23e3b4.zip’
#
# Training data set 1 100%[===================>] 926.03M  14.0MB/s    in 74s
#
# 2021-04-29 10:28:04 (12.5 MB/s) - ‘Training data set 1b23e3b4.zip’ saved [971014870/971014870]

# %%
# !unzip Training\ data\ set\ 1b23e3b4.zip
# Out:
# Archive:  Training data set 1b23e3b4.zip
#  extracting: LORD-6305-6000-69503.zip
#  extracting: LORD-6305-6000-69504.zip
#  extracting: LORD-6305-6000-69505.zip
#  extracting: LORD-6305-6000-69506.zip
#  extracting: LORD-6305-6000-69507.zip

# %%
# !unzip /content/Training data set 1b23e3b4.zip
# Out:
# unzip:  cannot find or open /content/Training, /content/Training.zip or /content/Training.ZIP.

# %%
# !unzip LORD-6305-6000-69503.zip
# Out:
# Archive:  LORD-6305-6000-69503.zip
#    creating: content/LORD-6305-6000-69503/
#    creating: content/LORD-6305-6000-69503/year=2020/
#    creating: content/LORD-6305-6000-69503/year=2020/month=10/
#    creating: content/LORD-6305-6000-69503/year=2020/month=10/day=19/
#    creating: content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=13/
#   inflating: content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=13/balena_1603112606562500_1603113206218750_LORD-6305-6000-69503.csv
#   inflating: content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=13/balena_1603113206234375_1603113806218750_LORD-6305-6000-69503.csv
#   inflating: content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=13/balena_1603113806234375_1603114406218750_LORD-6305-6000-69503.csv
#   inflating: content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=13/balena_1603114406234375_1603115006218750_LORD-6305-6000-69503.csv
# ...

# %%
# !ls -alrt
# Out:
# total 1896552
# -rw-rw-r-- 1 root root 196929504 Mar 24 19:44  LORD-6305-6000-69503.zip
# -rw-rw-r-- 1 root root 194407295 Mar 24 22:27  LORD-6305-6000-69504.zip
# -rw-rw-r-- 1 root root 194407295 Mar 24 22:27  LORD-6305-6000-69505.zip
# -rw-rw-r-- 1 root root 194369413 Mar 24 22:27  LORD-6305-6000-69506.zip
# -rw-rw-r-- 1 root root 190900461 Mar 24 23:46  LORD-6305-6000-69507.zip
# -rw-r--r-- 1 root root 971014870 Mar 25 00:33 'Training data set 1b23e3b4.zip'
# drwxr-xr-x 4 root root      4096 Apr 21 13:38  .config
# drwxr-xr-x 1 root root      4096 Apr 21 13:39  sample_data
# drwxr-xr-x 1 root root      4096 Apr 29 10:24  ..
# drwxr-xr-x 3 root root      4096 Apr 29 10:32  content
# drwx------ 5 root root      4096 Apr 29 10:37  drive
# drwxr-xr-x 1 root root      4096 Apr 29 10:37  .

# %%
# !cat /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=04/balena_1603080207593750_1603080807328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=05/balena_1603083807343750_1603084407328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=06/balena_1603087407343750_1603088007078125_LORD-6305-6000-69503.csv  > sensor1.csv

# %%
# !cat /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=04/balena_1603080807343750_1603081407328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=05/balena_1603084407343750_1603085007328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=06/balena_1603088007093750_1603088607078125_LORD-6305-6000-69503.csv > sensor2.csv
# !cat /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=04/balena_1603081407343750_1603082007328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=05/balena_1603085007343750_1603085607328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=06/balena_1603088607093750_1603089207078125_LORD-6305-6000-69503.csv > sensor3.csv
# !cat /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=04/balena_1603082007343750_1603082607328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=05/balena_1603085607343750_1603086207328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=06/balena_1603089207093750_1603089807078125_LORD-6305-6000-69503.csv > sensor4.csv
# !cat /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=04/balena_1603082607343750_1603083207328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=05/balena_1603086207343750_1603086807328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=06/balena_1603089807093750_1603090407078125_LORD-6305-6000-69503.csv > sensor5.csv
# !cat /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=04/balena_1603083207343750_1603083807328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=05/balena_1603086807343750_1603087407328125_LORD-6305-6000-69503.csv /content/content/LORD-6305-6000-69503/year=2020/month=10/day=19/hour=06/balena_1603090407093750_1603091007078125_LORD-6305-6000-69503.csv > sensor6.csv

# %%
import pandas as pd
df1 = pd.read_csv('/content/sensor1.csv')
df2 = pd.read_csv('/content/sensor2.csv')
df3 = pd.read_csv('/content/sensor3.csv')
df4 = pd.read_csv('/content/sensor4.csv')
df5 = pd.read_csv('/content/sensor5.csv')
df6 = pd.read_csv('/content/sensor6.csv')

# %%
df1
# Out:
#                       _t                ch1  ... month                 date
# 0       1603080207593750  9.817719459533691  ...    10  2020-10-19 04:03:27
# 1       1603080207609375  9.817719459533691  ...    10  2020-10-19 04:03:27
# 2       1603080207625000  9.817719459533691  ...    10  2020-10-19 04:03:27
# 3       1603080207640625    9.8152437210083  ...    10  2020-10-19 04:03:27
# 4       1603080207656250  9.817719459533691  ...    10  2020-10-19 04:03:27
# ...                  ...                ...  ...   ...                  ...
# 115197  1603088007015625  9.822669982910156  ...    10  2020-10-19 06:13:27
# 115198  1603088007031250  9.817719459533691  ...    10  2020-10-19 06:13:27
# 115199  1603088007046875    9.8152437210083  ...    10  2020-10-19 06:13:27
# 115200  1603088007062500  9.812768936157227  ...    10  2020-10-19 06:13:27
# 115201  1603088007078125  9.820194244384766  ...    10  2020-10-19 06:13:27
#
# [115202 rows x 8 columns]

# %%
df1 = df1.add_prefix('1')
df2 = df1.add_prefix('2')
df3 = df1.add_prefix('3')
df4 = df1.add_prefix('4')
df5 = df1.add_prefix('5')
df6 = df1.add_prefix('6')

# %%
df1.columns
# Out:
# Index(['1_t', '1ch1', '1ch2', '1ch3', '1hour', '1day', '1month', '1date'], dtype='object')

# %%
df = pd.concat([df1[['1ch1','1ch2','1ch3']],df2[['2ch1','2ch2','2ch3']],df3[['3ch1','3ch2','3ch3']],df4[['4ch1','4ch2','4ch3']],df5[['5ch1','5ch2','5ch3']],df6[['6ch1','6ch2','6ch3']]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-22d4e360795e> in <module>()
# ----> 1 df = pd.concat([df1[['1ch1','1ch2','1ch3']],df2[['2ch1','2ch2','2ch3']],df3[['3ch1','3ch2','3ch3']],df4[['4ch1','4ch2','4ch3']],df5[['5ch1','5ch2','5ch3']],df6[['6ch1','6ch2','6ch3']]])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df
# Out:
#                      1_t               1ch1  ... 61month               61date
# 0       1603080207593750  9.817719459533691  ...     NaN                  NaN
# 1       1603080207609375  9.817719459533691  ...     NaN                  NaN
# 2       1603080207625000  9.817719459533691  ...     NaN                  NaN
# 3       1603080207640625    9.8152437210083  ...     NaN                  NaN
# 4       1603080207656250  9.817719459533691  ...     NaN                  NaN
# ...                  ...                ...  ...     ...                  ...
# 115197               NaN                NaN  ...      10  2020-10-19 06:13:27
# 115198               NaN                NaN  ...      10  2020-10-19 06:13:27
# 115199               NaN                NaN  ...      10  2020-10-19 06:13:27
# 115200               NaN                NaN  ...      10  2020-10-19 06:13:27
# 115201               NaN                NaN  ...      10  2020-10-19 06:13:27
#
# [691212 rows x 48 columns]
